# %%
import os
import math
import pandas as pd
from dotenv import load_dotenv

# Explicitly providing path to '.env'
from pathlib import Path  # Python 3.6+ only
# Load .env variables
_ = load_dotenv(dotenv_path=f"{Path().resolve().parents[1]}/src/.env")

# with the new api
from importnb import imports
with imports("ipynb"):
    from utils import to_timestamp, df_data_sensors, missing_data, correlation_data, df_to_csv, df_from_csv
# Out:
# PM2.5: 35.9, AQI: 102
# PM2.5: 35.9, Measure Level: MeasureLevels.UNHEALTHY_FOR_SENSITIVE_GROUPS, Range Values: Min: 35.5, Max: 55.4
# AQI: 102, Measure Level: MeasureLevels.UNHEALTHY_FOR_SENSITIVE_GROUPS, Range Values: Min: 101, Max: 150

# %% [markdown]
# ## Reference

# %%
# Load Tangara Reference
df_reference = df_from_csv("reference.csv", datafolder='2_features', dtindex=False)
print(f"Tangara Sensor Reference: {df_reference['ID'].values[0]}")

df_reference
# Out:
# 2024-07-15 18:49:29.665 | DEBUG    | utils:df_from_csv:340 - Load DataFrame: /home/sebaxtian/Workspaces/Tangara/tangara-evaluation/src/data/2_features/reference.csv
# Tangara Sensor Reference: TANGARA_25BE
#              ID  GEOHASH              MAC  \
# 0  TANGARA_25BE  d29e6de  D29ESP32DE725BE
#
#                              GEOLOCATION  LATITUDE  LONGITUDE
# 0  3.3982086181640625 -76.52595520019531  3.398209 -76.525955

# %% [markdown]
# ## Targets

# %%
# Load Tangara Targets
df_targets = df_from_csv("targets.csv", datafolder='2_features', dtindex=False)
print(f"Total Tangara Sensor Targets: {len(df_targets)}")

df_targets
# Out:
# 2024-07-15 18:49:29.698 | DEBUG    | utils:df_from_csv:340 - Load DataFrame: /home/sebaxtian/Workspaces/Tangara/tangara-evaluation/src/data/2_features/targets.csv
# Total Tangara Sensor Targets: 23
#               ID  GEOHASH              MAC  \
# 0   TANGARA_B7BE  d29e6de  D29ESP32DE0B7BE
# 1   TANGARA_C752  d29e6de  D29ESP32DE0C752
# 2   TANGARA_A682  d29e6d7  D29ESP32DE3A682
# 3   TANGARA_ADD6  d29e6de  D29ESP32DE3ADD6
# 4   TANGARA_B08A  d29e6de  D29ESP32DE3B08A
# 5   TANGARA_B9CA  d29e6de  D29ESP32DE3B9CA
# 6   TANGARA_BC5A  d29e6ds  D29ESP32DE3BC5A
# 7   TANGARA_BCC6  d29e6de  D29ESP32DE3BCC6
# 8   TANGARA_BD5E  d29e6de  D29ESP32DE3BD5E
# 9   TANGARA_BE12  d29e6de  D29ESP32DE3BE12
# 10  TANGARA_79CA  d29e6de  D29ESP32DE679CA
# 11  TANGARA_0E26  d29e6de  D29ESP32DE70E26
# 12  TANGARA_1402  d29e6de  D29ESP32DE71402
# 13  TANGARA_157E  d29e6de  D29ESP32DE7157E
# 14  TANGARA_18DA  d29e6de  D29ESP32DE718DA
# 15  TANGARA_1DE2  d29e6de  D29ESP32DE71DE2
# ...

# %% [markdown]
# ## Tangaras

# %%
# Tangaras from Reference and Targets
df_tangaras = pd.concat([df_reference, df_targets], ignore_index=True)
print(f"Total Tangara Sensors: {len(df_tangaras)}")

df_tangaras
# Out:
# Total Tangara Sensors: 24
#               ID  GEOHASH              MAC  \
# 0   TANGARA_25BE  d29e6de  D29ESP32DE725BE
# 1   TANGARA_B7BE  d29e6de  D29ESP32DE0B7BE
# 2   TANGARA_C752  d29e6de  D29ESP32DE0C752
# 3   TANGARA_A682  d29e6d7  D29ESP32DE3A682
# 4   TANGARA_ADD6  d29e6de  D29ESP32DE3ADD6
# 5   TANGARA_B08A  d29e6de  D29ESP32DE3B08A
# 6   TANGARA_B9CA  d29e6de  D29ESP32DE3B9CA
# 7   TANGARA_BC5A  d29e6ds  D29ESP32DE3BC5A
# 8   TANGARA_BCC6  d29e6de  D29ESP32DE3BCC6
# 9   TANGARA_BD5E  d29e6de  D29ESP32DE3BD5E
# 10  TANGARA_BE12  d29e6de  D29ESP32DE3BE12
# 11  TANGARA_79CA  d29e6de  D29ESP32DE679CA
# 12  TANGARA_0E26  d29e6de  D29ESP32DE70E26
# 13  TANGARA_1402  d29e6de  D29ESP32DE71402
# 14  TANGARA_157E  d29e6de  D29ESP32DE7157E
# 15  TANGARA_18DA  d29e6de  D29ESP32DE718DA
# 16  TANGARA_1DE2  d29e6de  D29ESP32DE71DE2
# 17  TANGARA_211E  d29e6de  D29ESP32DE7211E
# 18  TANGARA_25F2  d29e6de  D29ESP32DE725F2
# 19  TANGARA_298A  d29e6de  D29ESP32DE7298A
# ...

# %% [markdown]
# ## PM2.5 Raw Data

# %%
# Start Date Time ISO 8601 Format, TZ='America/Bogota' -05:00
START_ISO8601_DATETIME = os.getenv("START_ISO8601_DATETIME", None)
start_timestamp = to_timestamp(START_ISO8601_DATETIME)
# End Date Time ISO 8601 Format, TZ='America/Bogota' -05:00
END_ISO8601_DATETIME = os.getenv("END_ISO8601_DATETIME", None)
end_timestamp = to_timestamp(os.getenv("END_ISO8601_DATETIME", None))

# GROUP BY TIME
GROUP_BY_TIME = os.getenv("GROUP_BY_TIME", None)

print(f'Since: {START_ISO8601_DATETIME} -> {start_timestamp}, Until: {END_ISO8601_DATETIME} -> {end_timestamp}')
print(f"Group by Time: {GROUP_BY_TIME}")
# Out:
# 2024-07-15 18:49:29.742 | DEBUG    | utils:to_timestamp:99 - datetime_iso8601: 2024-07-15T19:49:00-05:00, Timestamp: 1721090940000
# 2024-07-15 18:49:29.743 | DEBUG    | utils:to_timestamp:99 - datetime_iso8601: 2024-07-15T20:49:00-05:00, Timestamp: 1721094540000
# Since: 2024-07-15T19:49:00-05:00 -> 1721090940000, Until: 2024-07-15T20:49:00-05:00 -> 1721094540000
# Group by Time: 30s

# %%
# PM2.5 Data Frame Sensors
df_pm25_raw = df_data_sensors(df_tangaras, start_timestamp, end_timestamp, 'pm25', GROUP_BY_TIME)
df_pm25_raw
#df_pm25_raw.shape
# Out:
# 2024-07-15 18:49:29.752 | DEBUG    | utils:query_measure:192 - sql_query: SELECT last("pm25") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE725BE') AND time >= 1721090940000ms AND time <= 1721094540000ms GROUP BY time(30s) fill(null); SELECT last("pm25") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE0B7BE') AND time >= 1721090940000ms AND time <= 1721094540000ms GROUP BY time(30s) fill(null); SELECT last("pm25") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE0C752') AND time >= 1721090940000ms AND time <= 1721094540000ms GROUP BY time(30s) fill(null); SELECT last("pm25") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3A682') AND time >= 1721090940000ms AND time <= 1721094540000ms GROUP BY time(30s) fill(null); SELECT last("pm25") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3ADD6') AND time >= 1721090940000ms AND time <= 1721094540000ms GROUP BY time(30s) fill(null); SELECT last("pm25") FROM "fixed_stations_01" WHERE ("name" = 'D29ESP32DE3B08A') AND time 
# ...

# %% [markdown]
# ## Descriptive Statistics

# %%
# Describe Data
df_pm25_raw.describe()
# Out:
#        TANGARA_25BE  TANGARA_B7BE  TANGARA_C752  TANGARA_A682  TANGARA_ADD6  \
# count    110.000000     81.000000     88.000000    118.000000    120.000000
# mean       5.372727      4.629630      4.647727      4.144068      4.408333
# std        0.788205      0.813087      0.773702      0.670188      0.715916
# min        4.000000      3.000000      3.000000      3.000000      3.000000
# 25%        5.000000      4.000000      4.000000      4.000000      4.000000
# 50%        5.000000      4.000000      5.000000      4.000000      4.000000
# 75%        6.000000      5.000000      5.000000      4.000000      5.000000
# max        7.000000      7.000000      7.000000      6.000000      7.000000
#
#        TANGARA_B08A  TANGARA_B9CA  TANGARA_BC5A  TANGARA_BCC6  TANGARA_BD5E  \
# count    111.000000    120.000000    117.000000    113.000000    113.000000
# mean       4.756757      4.208333      4.811966      4.061947      5.026549
# ...

# %% [markdown]
# ## Missing Data

# %%
import warnings
warnings.filterwarnings('ignore')

# Missing Data Threshold
threshold_data = float(os.getenv("THRESHOLD_MISSING_DATA", None))
print(f'Threshold Missing Data: {int(threshold_data * 100)}%')

# DataFrame Report for Missing Data PM25
df_pm25_missing_data = pd.DataFrame({'ID': [], 'TO_BE_CHECKED': [], 'DATA_PERCENT': [], 'MISSING_DATA_PERCENT': [], 'THRESHOLD_MISSING_DATA': []})

# For each Tangara sensor
for id_tangara_sensor in df_pm25_raw.columns:
    df_pm25_sensor = df_pm25_raw[[id_tangara_sensor]]
    # To be checked
    to_be_checked, data_percent, missing_data_percent = missing_data(df_pm25_sensor, threshold_data)
    if to_be_checked:
        print(f"Tangara Sensor: {id_tangara_sensor}, To be checked: {to_be_checked}, Data: {data_percent}%, Missing Data: {missing_data_percent}%, Threshold: {threshold_data}%")
        # Drop Tangara Sensor from original dataframe
        # df_pm25_raw = df_pm25_raw.drop(id_tangara_sensor, axis=1)
    
    # Insert into DataFrame Report
    df_pm25_missing_data.loc[len(df_pm25_missing_data.index)] = [id_tangara_sensor, to_be_checked, data_percent, missing_data_percent, threshold_data]

df_pm25_missing_data
# Out:
# 2024-07-15 18:49:30.228 | DEBUG    | utils:missing_data:230 - Tangara Sensor: TANGARA_25BE, To be checked: False, Data: 91%, Missing Data: 9%, Threshold: 80%
# 2024-07-15 18:49:30.233 | DEBUG    | utils:missing_data:230 - Tangara Sensor: TANGARA_B7BE, To be checked: True, Data: 67%, Missing Data: 33%, Threshold: 80%
# 2024-07-15 18:49:30.237 | DEBUG    | utils:missing_data:230 - Tangara Sensor: TANGARA_C752, To be checked: True, Data: 73%, Missing Data: 27%, Threshold: 80%
# 2024-07-15 18:49:30.242 | DEBUG    | utils:missing_data:230 - Tangara Sensor: TANGARA_A682, To be checked: False, Data: 98%, Missing Data: 2%, Threshold: 80%
# 2024-07-15 18:49:30.246 | DEBUG    | utils:missing_data:230 - Tangara Sensor: TANGARA_ADD6, To be checked: False, Data: 99%, Missing Data: 1%, Threshold: 80%
# 2024-07-15 18:49:30.251 | DEBUG    | utils:missing_data:230 - Tangara Sensor: TANGARA_B08A, To be checked: False, Data: 92%, Missing Data: 8%, Threshold: 80%
# ...

# %%
# Save DataFrame Report for Missing Data PM25 into CSV file
df_pm25_missing_data.set_index('ID', inplace=True)
df_to_csv(df_pm25_missing_data, "pm25_missing.csv", datafolder='2_features')
# Out:
# 2024-07-15 18:49:30.357 | DEBUG    | utils:df_to_csv:311 - Save DataFrame: /home/sebaxtian/Workspaces/Tangara/tangara-evaluation/src/data/2_features/pm25_missing.csv

# %% [markdown]
# ## Data Correlation

# %%
# Data Correlation Threshold
threshold_correlation = float(os.getenv("THRESHOLD_CORRELATION_DATA", None))
print(f'Threshold Correlation Data: {int(threshold_correlation * 100)}%')

# Tangara Sensor Reference
ID_TANGARA_REFERENCE = df_reference['ID'].values[0]
df_pm25_reference = df_pm25_raw[[ID_TANGARA_REFERENCE]]

# DataFrame Report for Data Correlation PM25
df_pm25_correlation_data = pd.DataFrame({'ID_REFERENCE': [], 'ID_TARGET': [], 'THERE_IS_CORRELATION': [], 'CORRELATION_VALUE': [], 'THRESHOLD_CORRELATION': []})

# For each Tangara Sensor Target
for id_tangara_sensor in df_pm25_raw.columns:
    if id_tangara_sensor != ID_TANGARA_REFERENCE:
        # Target Tangara Sensor
        df_pm25_target = df_pm25_raw[[id_tangara_sensor]]
        
        # To be checked
        if not math.isnan(df_pm25_reference.std()):
            has_corr, corr = correlation_data(df_pm25_reference, df_pm25_target, threshold_correlation)
            if not has_corr:
                print(f"Tangara Sensor Reference: {ID_TANGARA_REFERENCE}, Tangara Sensors Target: {df_pm25_target.columns[0]}, There is correlation: {has_corr}, Correlation: {float("{:.2f}".format(corr))}, Threshold: {threshold_correlation}")

                # Drop Tangara Sensor from original dataframe
                # df_pm25_raw = df_pm25_raw.drop(id_tangara, axis=1)
            
            # Insert into DataFrame Report
            df_pm25_correlation_data.loc[len(df_pm25_correlation_data.index)] = [ID_TANGARA_REFERENCE, df_pm25_target.columns[0], has_corr, float("{:.2f}".format(corr)), threshold_correlation]

df_pm25_correlation_data
# Out:
# 2024-07-15 18:49:30.376 | DEBUG    | utils:correlation_data:287 - Tangara Sensor Reference: TANGARA_25BE, Tangara Sensors Target: TANGARA_B7BE, There is correlation: False, Correlation: 0.73, Threshold: 0.8
# 2024-07-15 18:49:30.382 | DEBUG    | utils:correlation_data:287 - Tangara Sensor Reference: TANGARA_25BE, Tangara Sensors Target: TANGARA_C752, There is correlation: False, Correlation: 0.66, Threshold: 0.8
# 2024-07-15 18:49:30.389 | DEBUG    | utils:correlation_data:287 - Tangara Sensor Reference: TANGARA_25BE, Tangara Sensors Target: TANGARA_A682, There is correlation: False, Correlation: 0.68, Threshold: 0.8
# 2024-07-15 18:49:30.396 | DEBUG    | utils:correlation_data:287 - Tangara Sensor Reference: TANGARA_25BE, Tangara Sensors Target: TANGARA_ADD6, There is correlation: False, Correlation: 0.69, Threshold: 0.8
# ...

# %%
# Save DataFrame Report for Data Correlation PM25 into CSV file
df_pm25_correlation_data.set_index('ID_TARGET', inplace=True)
df_to_csv(df_pm25_correlation_data, "pm25_correlation.csv", datafolder='2_features')
# Out:
# 2024-07-15 18:49:30.548 | DEBUG    | utils:df_to_csv:311 - Save DataFrame: /home/sebaxtian/Workspaces/Tangara/tangara-evaluation/src/data/2_features/pm25_correlation.csv

# %%
# Save PM2.5 Data Frame Sensors into CSV file
df_to_csv(df_pm25_raw, "pm25_raw.csv")
# Out:
# 2024-07-15 18:49:30.563 | DEBUG    | utils:df_to_csv:311 - Save DataFrame: /home/sebaxtian/Workspaces/Tangara/tangara-evaluation/src/data/0_raw/pm25_raw.csv
